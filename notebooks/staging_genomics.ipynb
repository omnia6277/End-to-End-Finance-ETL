# %%
pip install pandas requests sqlalchemy pyodbc fastparquet openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to staging_db
server = "localhost"
database = "staging_genomics"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# Load Excel file
df = pd.read_excel(r"E:\Academic Study\Data Analysis Scholarship\CLS\Projects\Project - Financial Performance Analysis\10x Genomics, Inc\10x Genomics, Inc\TXG_BS.xlsx")

# Insert into staging table
df.to_sql("raw_balance_sheet", engine, if_exists="replace", index=False)
print("Excel data loaded into raw_balance_sheet!")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Excel data loaded into raw_balance_sheet!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to staging_db
server = "localhost"
database = "staging_genomics"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# Load Excel file
df = pd.read_excel(r"E:\Academic Study\Data Analysis Scholarship\CLS\Projects\Project - Financial Performance Analysis\10x Genomics, Inc\10x Genomics, Inc\TXG_CF.xlsx")

# Insert into staging table
df.to_sql("raw_cash_flow", engine, if_exists="replace", index=False)
print("Excel data loaded into raw_cash_flow!")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Excel data loaded into raw_cash_flow!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to staging_db
server = "localhost"
database = "staging_genomics"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# Load Excel file
df = pd.read_excel(r"E:\Academic Study\Data Analysis Scholarship\CLS\Projects\Project - Financial Performance Analysis\10x Genomics, Inc\10x Genomics, Inc\TXG_DERIVED.xlsx")

# Insert into staging table
df.to_sql("raw_derived_metrics", engine, if_exists="replace", index=False)
print("Excel data loaded into raw_derived_metrics!")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Excel data loaded into raw_derived_metrics!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to staging_db
server = "localhost"
database = "staging_genomics"

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# Load Excel file
df = pd.read_excel(r"E:\Academic Study\Data Analysis Scholarship\CLS\Projects\Project - Financial Performance Analysis\10x Genomics, Inc\10x Genomics, Inc\TXG_PL.xlsx")

# Insert into staging table
df.to_sql("raw_profit_loss", engine, if_exists="replace", index=False)
print("Excel data loaded into raw_profit_loss!")
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Excel data loaded into raw_profit_loss!
